# %%
import pandas as pd

df = pd.read_csv('../column_adder/final_processed_dataset.csv')

df
# Out:
#                                   author  \
# 0                         Mikhael Gewati
# 1                                    NaN
# 2                        Nur Jamal Shaid
# 3                          Reni Susanti,
# 4            Sakina Rakhma Diah Setiawan
# ...                                  ...
# 3111   Nafilah Sri Sagita K -detikHealth
# 3112   Sarah Oktaviani Alam -detikHealth
# 3113  Dinda Islami, detikTV -detikHealth
# 3114   Nafilah Sri Sagita K -detikHealth
# 3115   Nafilah Sri Sagita K -detikHealth
#
#                                               body_text            category  \
# 0     KOMPAS.com- Dari hamparan pesisir timur hingga...             finance
# 1     BANKIndonesia telah menurunkan suku bunga acua...             finance
# 2     JAKARTA, KOMPAS.com- Harga emas batangan yang ...             finance
# 3     BANDUNG, KOMPAS.com– Vaksin HPV NusaGard, vaks...             finance
# 4     JAKARTA, KOMPAS.com -Iklim usaha yang sehat ti...             finance
# ...

# %%
kompas_com = len(df[df['link'].str.contains('kompas.com', na=False)])
detik_com = len(df[df['link'].str.contains('detik.com', na=False)])
investor_id = len(df[df['link'].str.contains('investor.id', na=False)])

# %%
print(f"Kompas: {kompas_com}")
print(f"Detik: {detik_com}")
print(f"Investor: {investor_id}")
# Out:
# Kompas: 2462
# Detik: 654
# Investor: 0
